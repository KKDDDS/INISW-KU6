# %%
문자 => 문자
. => 아무거나 1글자
\글자 => escape (r'', re.escape)
{n} => n번 반복
{n, m} => 최소 n개에서 최대 m개
* => {0,}
+ => {1,}
? => 있거나, 없거나
[] => or, 범위
\d => [0-9]
\s => [\t\n ...]
\w => [a-zA-Z0-9]
() => group(capturing)
(?:) => capture X

# %%
Client --------- HTTP --------- Server
        Request        Response
                  TCP => Syn/Ack (요청/응답 쌍)
                  IP  => Packet (Header/Data-Body)
URL/URI => 원격(Server

# %%
from urllib import robotparser

# %%
rp = robotparser.RobotFileParser()

# %%
rp.set_url('https://news.naver.com/robots.txt')
rp.read()

# %%
#rp.can+fetch('*', '/')
rp.can_fetch('*','/main/imagemontage'), rp.can_fetch('Yeti','/main/imagemontage')
# Out:
# (False, True)

# %%
rp.set_url('https://www.korea.ac.kr/robots.txt')
rp.read()

# %%
rp.can_fetch('*','/') #True
# Out:
# False

# %%
from urllib.request import urlopen, Request

# %%
Client ----> HTTP ----> Server
            TCP/IP
             Bytes
Request(Header/Body) -> dict/list/문자->bytes
        Response(header/Body)
HTML Parsing <- text.decoding <- Bytes <- text/html, images/jpeg
항상 Header 확인

# %%
resp = urlopen('https://www.google.com')

# %%
type(resp)
# Out:
# http.client.HTTPResponse

# %%
resp.status, resp.reason, resp.getheaders()
#1. Status Code 값 제일 먼저 확인
#2. Reason
#3. Header -> contenttype, length, ...
# Out:
# (200,
#  'OK',
#  [('Date', 'Tue, 11 Mar 2025 02:14:58 GMT'),
#   ('Expires', '-1'),
#   ('Cache-Control', 'private, max-age=0'),
#   ('Content-Type', 'text/html; charset=ISO-8859-1'),
#   ('Content-Security-Policy-Report-Only',
#    "object-src 'none';base-uri 'self';script-src 'nonce-_B4DOTVO99CnTgCIoG6JXg' 'strict-dynamic' 'report-sample' 'unsafe-eval' 'unsafe-inline' https: http:;report-uri https://csp.withgoogle.com/csp/gws/other-hp"),
#   ('Accept-CH', 'Sec-CH-Prefers-Color-Scheme'),
#   ('P3P', 'CP="This is not a P3P policy! See g.co/p3phelp for more info."'),
#   ('Server', 'gws'),
#   ('X-XSS-Protection', '0'),
#   ('X-Frame-Options', 'SAMEORIGIN'),
#   ('Set-Cookie',
#    'AEC=AVcja2c68VMqESWkvL3HBMH4Vnfqsd69xoZ92Y-IgxclXi1zh7PIP-xVAQ; expires=Sun, 07-Sep-2025 02:14:58 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax'),
#   ('Set-Cookie',
# ...

# %%
msg = resp.read()

# %%
import re
resp.headers.get('content-type')
charset = re.search(r'charset=(.+);?', resp.headers.get('content-type')).group(1)
type(msg), type(msg.decode(charset))
# Out:
# (bytes, str)

# %%
1. Status Code / Reason
2. Encoding/Decoding => Charset, HtmlEntities(Percent Encoding), Hexa Decimal

# %%
resp = urlopen('https://www.naver.com')
msg = resp.read()

# %%
msg
# Out:
# b'   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x
# ...

# %%
scheme => https://
host => www.google.com
path => /search?
params => q: %EC%B9%B4%EB%A6%AC%EB%82%98& ===> Percent Encoding %(Hexadecimal 16진수)
          sca_esv: 3ef60f3b3aecdda5&
          sxsrf: AHTn8zqZUt5Fof8mAxKO2bK2-ArLc-MfZw%3A1741660378382&
          source: hp&ei=2qDPZ6rNFJKO2roPl7a7UA&
          iflsig:ACkRmUkAAAAAZ8-u6uvosGXPavTIb2eTZFksY3oejLqX&
          ved=0ahUKEwiqoq7B_oCMAxUSh1YBHRfbDgoQ4dUDCBo&uact=5&oq=%EC%B9%B4%EB%A6%AC%EB%82%98&gs_lp=...&sclient=gws-wiz

# %%
1byte => 0000 0000
         0111 1111 => ASCII
         1~ => non ASCII
2byte => Trigem, 완성형, 확장완성형
UNICODE
ASCII => 65:A, 97:a
(str)A-65 => (bytes)A-65
Non ASCII => 1~ 0~(65) => A? => Charset(Encoding)
(str) => (Bytes) 16진수 => Percent
HTML => Markup => <Tag></Tag>
1<3, 기호들 => HTML Entities
< => &; => &lt; 한글=>10진수 &10진수;

# %%
# %A%B%C%D%E

# %%
from urllib.parse import quote, unquote

# %%
quote('카')
# Out:
# '%EC%B9%B4'

# %%
url = 'https://www.google.com/search?q=%EC%B9%B4%EB%A6%AC%EB%82%98&rlz=1C1IBEF_koKR1000KR1005&oq=%EC%B9%B4%EB%A6%AC%EB%82%98&gs_lcrp=EgZjaHJvbWUqDAgAECMYJxiABBiKBTIMCAAQIxgnGIAEGIoFMgwIARAuGEMYgAQYigUyCggCEAAYsQMYgAQyCggDEAAYsQMYgAQyCggEEAAYsQMYgAQyBwgFEAAYgAQyDQgGEAAYgwEYsQMYgAQyBwgHEAAYgAQyBwgIEAAYgAQyDQgJEAAYgwEYsQMYgATSAQgxMzkwajBqN6gCALACAA&sourceid=chrome&ie=UTF-8'
resp = urlopen(url)

# %%
# Non ASCII -> quote -> Bytes(Percent Encoding-Hexadecimal)형태로 변환해야 함

# %%
unquote(resp.geturl())
# Out:
# 'https://www.google.com/search?q=카리나&rlz=1C1IBEF_koKR1000KR1005&oq=카리나&gs_lcrp=EgZjaHJvbWUqDAgAECMYJxiABBiKBTIMCAAQIxgnGIAEGIoFMgwIARAuGEMYgAQYigUyCggCEAAYsQMYgAQyCggDEAAYsQMYgAQyCggEEAAYsQMYgAQyBwgFEAAYgAQyDQgGEAAYgwEYsQMYgAQyBwgHEAAYgAQyBwgIEAAYgAQyDQgJEAAYgwEYsQMYgATSAQgxMzkwajBqN6gCALACAA&sourceid=chrome&ie=UTF-8'

# %%
#resp.getheaders() => content-type: ISO-8859-1
#resp.read().decode()

from html import unescape, escape
src = ' &#51060;&#46041;&#54616;&#51648'
unescape(src)
# Out:
# ' 이동하지'

# %%
escape('몇'), escape('<')
# Out:
# ('몇', '&lt;')

# %%
unescape(resp.read().decode())
# Out:
# ''

# %%
https://httpbin.org
