# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.groupby('sex')

# %%
tips.groupby('sex').mean().plot.bar()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_20644\1953901929.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tips.groupby('sex').mean().plot.bar()
# <Axes: xlabel='sex'>

# %%
tips = tips[['total_bill', 'tip']]

# %%
tips.set_index('tip').plot.bar()
# Out:
# <Axes: xlabel='tip'>

# %%
print(tips.head())
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
tips.pivot_table(index = 'day', columns=['tip','total_bill'])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_20644\725307384.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   tips.pivot_table(index = 'day', columns=['tip','total_bill'])
#             size                                                        ...  \
# tip        1.00                    1.01  1.10  1.17  1.25               ...
# total_bill 3.07  5.75  7.25  12.60 16.99 12.90 32.83 8.51  10.07 10.51  ...
# day                                                                     ...
# Thur         NaN   NaN   NaN   NaN   NaN   NaN   NaN   2.0   NaN   NaN  ...
# Fri          NaN   2.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Sat          1.0   NaN   1.0   2.0   NaN   2.0   2.0   NaN   2.0   2.0  ...
# Sun          NaN   NaN   NaN   NaN   2.0   NaN   NaN   NaN   NaN   NaN  ...
#
#
# ...

# %%
import pandas as pd

# %%
pd.plotting.boxplot(tips)
# Out:
# <Axes: >

# %%
tips.boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(x='sex',y='tip', data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x='sex',y='tip', data = tips, hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>
