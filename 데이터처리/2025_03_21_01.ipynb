# %%
[(1,2,3,'4',5)] #행을 묶어버리면 하나의 데이터로 보게됨.
[1,2,3,'3',5]
[1,2,3,'1',5]
# Out:
# [1, 2, 3, '1', 5]

# %%
import numpy as np

# %%
x = np.rec.array([('Rex', 9, 81.0), ('Fido', 3, 27.0)],
            dtype=[('name','U10'),('age','i4'),('weight','f4')]) #rec을 쓰면 .name도 에러 없이 쓸 수 있다

# %%
x['name']
# Out:
# array(['Rex', 'Fido'], dtype='<U10')

# %%
x.name
# Out:
# array(['Rex', 'Fido'], dtype='<U10')

# %%
programming excel

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
dir(tips)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe(include=['category'])
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
tips.loc[0:3] #편의성 고려한 함수
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2

# %%
tips.iloc[0:3] #python에서 배운대로 프로그램이 짜임
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips[['tip', 'total_bill']] #pensing indexing, 차원을 유지해줘서 데이터 뽑기 가능(2차원)
# Out:
#       tip  total_bill
# 0    1.01       16.99
# 1    1.66       10.34
# 2    3.50       21.01
# 3    3.31       23.68
# 4    3.61       24.59
# ..    ...         ...
# 239  5.92       29.03
# 240  2.00       27.18
# 241  2.00       22.67
# 242  1.75       17.82
# 243  3.00       18.78
#
# [244 rows x 2 columns]

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
tips.tip > 2 #boolean indexing
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 239     True
# 240    False
# 241    False
# 242    False
# 243     True
# Name: tip, Length: 244, dtype: bool

# %%
tips[tips.tip > 2] #boolean indexing
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [166 rows x 7 columns]

# %%
tips.iloc[0,3] #python 기반이기에, 숫자 데이터만
# Out:
# 'No'

# %%
tips.loc[0,'smoker'] #여러개 뽑는건데 하나 뽑은거
# Out:
# 'No'

# %%
tips.iat[0,3]
# Out:
# 'No'

# %%
tips.at[0,'smoker'] #데이터 하나만 뽑는거
# Out:
# 'No'

# %%
# %timeit tips.iat[0,3]
# Out:
# 14.1 µs ± 167 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
tips.loc[0, 'smoker']
# Out:
# 'Yes'

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.loc[tips.sex == 'Female','smoker'] = 'Yes'  #broadcasting이 되기 떄문에 다 바꿔버릴 수 있음

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female    Yes   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female    Yes   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female    Yes  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.filter(regex='^t')
# Out:
#      total_bill   tip    time
# 0         16.99  1.01  Dinner
# 1         10.34  1.66  Dinner
# 2         21.01  3.50  Dinner
# 3         23.68  3.31  Dinner
# 4         24.59  3.61  Dinner
# ..          ...   ...     ...
# 239       29.03  5.92  Dinner
# 240       27.18  2.00  Dinner
# 241       22.67  2.00  Dinner
# 242       17.82  1.75  Dinner
# 243       18.78  3.00  Dinner
#
# [244 rows x 3 columns]

# %%
tips.select_dtypes(['float64', 'category'])
# Out:
#      total_bill   tip     sex smoker   day    time
# 0         16.99  1.01  Female    Yes   Sun  Dinner
# 1         10.34  1.66    Male     No   Sun  Dinner
# 2         21.01  3.50    Male     No   Sun  Dinner
# 3         23.68  3.31    Male     No   Sun  Dinner
# 4         24.59  3.61  Female    Yes   Sun  Dinner
# ..          ...   ...     ...    ...   ...     ...
# 239       29.03  5.92    Male     No   Sat  Dinner
# 240       27.18  2.00  Female    Yes   Sat  Dinner
# 241       22.67  2.00    Male    Yes   Sat  Dinner
# 242       17.82  1.75    Male     No   Sat  Dinner
# 243       18.78  3.00  Female    Yes  Thur  Dinner
#
# [244 rows x 6 columns]

# %%
tips.loc[0:10, lambda x: ['sex','smoker']]
# Out:
#        sex smoker
# 0   Female    Yes
# 1     Male     No
# 2     Male     No
# 3     Male     No
# 4   Female    Yes
# 5     Male     No
# 6     Male     No
# 7     Male     No
# 8     Male     No
# 9     Male     No
# 10    Male     No

# %%
tips.loc[lambda x: x.tip>3, ['sex','smoker']]
# Out:
#         sex smoker
# 2      Male     No
# 3      Male     No
# 4    Female    Yes
# 5      Male     No
# 7      Male     No
# ..      ...    ...
# 219  Female    Yes
# 221  Female    Yes
# 232    Male     No
# 238  Female    Yes
# 239    Male     No
#
# [98 rows x 2 columns]
